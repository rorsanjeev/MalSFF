# %%
import os
import pandas as pd
import numpy as np
import shutil
import hashlib

from base64 import b64encode, b64decode
from PIL import Image
import glob

import scipy
import scipy.misc
import array
import matplotlib.pyplot as plt
import math

# %%
Gatak = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/Gatak/'

# %%
root = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/'
images_path = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/'
# images_path = '/home/sanjeev/DL_Exp_Malware/DL_Prasad_Exp/Microsoft_PoC//'
fam = list(os.listdir(root))

# %%
fam
# Out:
# ['Kelihos_ver1',
#  'Lollipop',
#  'Vundo',
#  'Gatak',
#  'Tracur',
#  'Ramnit',
#  'Obfuscator.ACY',
#  'Simda',
#  'Kelihos_ver3']

# %%
# for i in fam:
#     folder_path = os.path.join(images_path,i)
#     os.mkdir(folder_path)
#     print(folder_path)
# Out:
# /home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Kelihos_ver1
# /home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Lollipop
# /home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Vundo
# /home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Gatak
# /home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Tracur
# /home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Ramnit
# /home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Obfuscator.ACY
# /home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Simda
# /home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Kelihos_ver3

# %%
images_path_Gatak = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Gatak/'

# %%
img_list_1 = []
for img in os.listdir(Gatak):
    Gatak_path = os.path.join(Gatak, img)
    img_list_1.append(Gatak_path)

# %%
for j in img_list_1:
    f = open(j, 'rb')
    ln = os.path.getsize(j)

    if ln < 10240:
        width = 32
    elif ln < 30720:
        width = 64
    elif ln < 61440:
        width = 128
    elif ln < 102400:
        width = 256
    elif ln < 204800:
        width = 384
    elif ln < 1024000:
        width = 512
    elif ln < 1536000:
        width = 1024
    else:
        width = 2048

    rem = ln%width
    a = array.array("B")
    a.fromfile(f, ln-rem)
    f.close()
    g = np.reshape(a, (len(a)//width, width))
    g = np.uint8(g)a
    
    #scipy.misc.imsave('/home/ubuntu/Desktop/BinImg/%s.png'%j, g)
    #print("Image saved for bin_id %s"%j)
    
    img = Image.fromarray(g)
    print(img)
   # str1 = Gatak_img + j
    
    #result = hashlib.md5(str1.encode())
    #str2 = result.hexdigest()
    img_asm = j.split('/')[-1]
    img_name = img_asm.split('.')[0] +'.png'
    img.save((images_path_Gatak+'/')+ img_name)
# Out:
# <PIL.Image.Image image mode=L size=2048x4070 at 0x7F4FA42DFDD0>
# <PIL.Image.Image image mode=L size=2048x4441 at 0x7F4FA44F8490>
# <PIL.Image.Image image mode=L size=2048x3603 at 0x7F4FA44F8F10>
# <PIL.Image.Image image mode=L size=2048x4285 at 0x7F4FA44F8FD0>
# <PIL.Image.Image image mode=L size=2048x29169 at 0x7F4FA44F8C10>
# <PIL.Image.Image image mode=L size=2048x28789 at 0x7F4FA44F8650>
# <PIL.Image.Image image mode=L size=1024x1348 at 0x7F4FA44F8550>
# <PIL.Image.Image image mode=L size=2048x25272 at 0x7F4FA44F8590>
# <PIL.Image.Image image mode=L size=2048x4204 at 0x7F4FA44F8650>
# <PIL.Image.Image image mode=L size=1024x1331 at 0x7F4FA44F8490>
# <PIL.Image.Image image mode=L size=1024x1462 at 0x7F4FA44F8FD0>
# <PIL.Image.Image image mode=L size=1024x1423 at 0x7F4FA44F8550>
# <PIL.Image.Image image mode=L size=1024x1193 at 0x7F4FA44F8490>
# <PIL.Image.Image image mode=L size=2048x25491 at 0x7F4FA44F8650>
# <PIL.Image.Image image mode=L size=2048x3910 at 0x7F4FA44F8F10>
# ...

# %% [markdown]
# ## 2

# %%
Kelihos_ver3 = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/Kelihos_ver3/'

root = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/'
images_path = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/'
fam = list(os.listdir(root))

# for i in fam:
#     folder_path = os.path.join(images_path,i)
#     os.mkdir(folder_path)
#     print(folder_path)

images_path_Kelihos_ver3_ver1 = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Kelihos_ver3/'

img_list_2 = []
for img in os.listdir(Kelihos_ver3):
    Kelihos_ver3_path = os.path.join(Kelihos_ver3, img)
    img_list_2.append(Kelihos_ver3_path)

for j in img_list_2:
    f = open(j, 'rb')
    ln = os.path.getsize(j)

    if ln < 10240:
        width = 32
    elif ln < 30720:
        width = 64
    elif ln < 61440:
        width = 128
    elif ln < 102400:
        width = 256
    elif ln < 204800:
        width = 384
    elif ln < 1024000:
        width = 512
    elif ln < 1536000:
        width = 1024
    else:
        width = 2048

    rem = ln%width
    a = array.array("B")
    a.fromfile(f, ln-rem)
    f.close()
    g = np.reshape(a, (len(a)//width, width))
    g = np.uint8(g)
    
    #scipy.misc.imsave('/home/ubuntu/Desktop/BinImg/%s.png'%j, g)
    #print("Image saved for bin_id %s"%j)
    
    img = Image.fromarray(g)
    print(img)
   # str1 = Gatak_img + j
    
    #result = hashlib.md5(str1.encode())
    #str2 = result.hexdigest()
    img_asm = j.split('/')[-1]
    img_name = img_asm.split('.')[0] +'.png'
    img.save((images_path_Kelihos_ver3_ver1+'/')+ img_name)
# Out:
# <PIL.Image.Image image mode=L size=384x469 at 0x7F4FA534FF90>
# <PIL.Image.Image image mode=L size=512x447 at 0x7F4FA42DFC90>
# <PIL.Image.Image image mode=L size=384x330 at 0x7F4FA534FA50>
# <PIL.Image.Image image mode=L size=384x468 at 0x7F4FA42DFC90>
# <PIL.Image.Image image mode=L size=384x439 at 0x7F4FA534FA50>
# <PIL.Image.Image image mode=L size=384x470 at 0x7F4FA534FF90>
# <PIL.Image.Image image mode=L size=384x442 at 0x7F4FA42DFD50>
# <PIL.Image.Image image mode=L size=384x358 at 0x7F4FA534FF90>
# <PIL.Image.Image image mode=L size=384x335 at 0x7F4FA42DFD50>
# <PIL.Image.Image image mode=L size=512x448 at 0x7F4FA534FA50>
# <PIL.Image.Image image mode=L size=384x438 at 0x7F4FA42DFC90>
# <PIL.Image.Image image mode=L size=384x386 at 0x7F4FA4AD78D0>
# <PIL.Image.Image image mode=L size=384x428 at 0x7F4FA42DFD50>
# <PIL.Image.Image image mode=L size=2048x16741 at 0x7F4FA42DFC90>
# <PIL.Image.Image image mode=L size=384x454 at 0x7F4FA42E2F90>
# ...

# %%
Kelihos_ver1 = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/Kelihos_ver1/'

root = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/'
images_path = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/'
fam = list(os.listdir(root))

# for i in fam:
#     folder_path = os.path.join(images_path,i)
#     os.mkdir(folder_path)
#     print(folder_path)

images_path_Kelihos_ver1_ver1 = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Kelihos_ver1/'

img_list_2 = []
for img in os.listdir(Kelihos_ver1):
    Kelihos_ver1_path = os.path.join(Kelihos_ver1, img)
    img_list_2.append(Kelihos_ver1_path)

for j in img_list_2:
    f = open(j, 'rb')
    ln = os.path.getsize(j)

    if ln < 10240:
        width = 32
    elif ln < 30720:
        width = 64
    elif ln < 61440:
        width = 128
    elif ln < 102400:
        width = 256
    elif ln < 204800:
        width = 384
    elif ln < 1024000:
        width = 512
    elif ln < 1536000:
        width = 1024
    else:
        width = 2048

    rem = ln%width
    a = array.array("B")
    a.fromfile(f, ln-rem)
    f.close()
    g = np.reshape(a, (len(a)//width, width))
    g = np.uint8(g)
    
    #scipy.misc.imsave('/home/ubuntu/Desktop/BinImg/%s.png'%j, g)
    #print("Image saved for bin_id %s"%j)
    
    img = Image.fromarray(g)
    print(img)
   # str1 = Gatak_img + j
    
    #result = hashlib.md5(str1.encode())
    #str2 = result.hexdigest()
    img_asm = j.split('/')[-1]
    img_name = img_asm.split('.')[0] +'.png'
    img.save((images_path_Kelihos_ver1_ver1+'/')+ img_name)
# Out:
# <PIL.Image.Image image mode=L size=384x484 at 0x7FE9BDECA7D0>
# <PIL.Image.Image image mode=L size=384x376 at 0x7FE9BDE5AF50>
# <PIL.Image.Image image mode=L size=384x482 at 0x7FE9BDE61D90>
# <PIL.Image.Image image mode=L size=384x462 at 0x7FE9BDE61510>
# <PIL.Image.Image image mode=L size=384x480 at 0x7FE9BDECA790>
# <PIL.Image.Image image mode=L size=384x479 at 0x7FE9BDF6DD90>
# <PIL.Image.Image image mode=L size=384x486 at 0x7FE9BDE5AF50>
# <PIL.Image.Image image mode=L size=384x470 at 0x7FE9BDECA790>
# <PIL.Image.Image image mode=L size=384x476 at 0x7FE9BDE61D90>
# <PIL.Image.Image image mode=L size=2048x2347 at 0x7FE9BDE5A390>
# <PIL.Image.Image image mode=L size=384x479 at 0x7FE9BDECA7D0>
# <PIL.Image.Image image mode=L size=384x480 at 0x7FE9BDE5AF50>
# <PIL.Image.Image image mode=L size=2048x2318 at 0x7FE9BDF6DD90>
# <PIL.Image.Image image mode=L size=2048x8979 at 0x7FEA945156D0>
# <PIL.Image.Image image mode=L size=384x470 at 0x7FE9BDE61510>
# ...

# %%
Lollipop = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/Lollipop/'

root = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/'
images_path = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/'
fam = list(os.listdir(root))

# for i in fam:
#     folder_path = os.path.join(images_path,i)
#     os.mkdir(folder_path)
#     print(folder_path)

images_path_Lollipop_ver1 = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Lollipop/'

img_list_2 = []
for img in os.listdir(Lollipop):
    Lollipop_path = os.path.join(Lollipop, img)
    img_list_2.append(Lollipop_path)

for j in img_list_2:
    f = open(j, 'rb')
    ln = os.path.getsize(j)

    if ln < 10240:
        width = 32
    elif ln < 30720:
        width = 64
    elif ln < 61440:
        width = 128
    elif ln < 102400:
        width = 256
    elif ln < 204800:
        width = 384
    elif ln < 1024000:
        width = 512
    elif ln < 1536000:
        width = 1024
    else:
        width = 2048

    rem = ln%width
    a = array.array("B")
    a.fromfile(f, ln-rem)
    f.close()
    g = np.reshape(a, (len(a)//width, width))
    g = np.uint8(g)
    
    #scipy.misc.imsave('/home/ubuntu/Desktop/BinImg/%s.png'%j, g)
    #print("Image saved for bin_id %s"%j)
    
    img = Image.fromarray(g)
    print(img)
   # str1 = Gatak_img + j
    
    #result = hashlib.md5(str1.encode())
    #str2 = result.hexdigest()
    img_asm = j.split('/')[-1]
    img_name = img_asm.split('.')[0] +'.png'
    img.save((images_path_Lollipop_ver1+'/')+ img_name)
# Out:
# <PIL.Image.Image image mode=L size=2048x7196 at 0x7FEA94500710>
# <PIL.Image.Image image mode=L size=2048x62009 at 0x7FEA945A9490>
# <PIL.Image.Image image mode=L size=2048x18737 at 0x7FE9BE1BDDD0>
# <PIL.Image.Image image mode=L size=2048x17084 at 0x7FE9BDE61510>
# <PIL.Image.Image image mode=L size=2048x51105 at 0x7FEA94500710>
# <PIL.Image.Image image mode=L size=2048x7233 at 0x7FE9BDF8D610>
# <PIL.Image.Image image mode=L size=2048x3663 at 0x7FE9BE53A510>
# <PIL.Image.Image image mode=L size=2048x18679 at 0x7FE9BE3B8E10>
# <PIL.Image.Image image mode=L size=2048x64639 at 0x7FEA94500710>
# <PIL.Image.Image image mode=L size=2048x17955 at 0x7FE9BE53A750>
# <PIL.Image.Image image mode=L size=2048x43082 at 0x7FE9BE53A510>
# <PIL.Image.Image image mode=L size=2048x7228 at 0x7FE9BDF81C10>
# <PIL.Image.Image image mode=L size=2048x6865 at 0x7FEA945A9FD0>
# <PIL.Image.Image image mode=L size=2048x50163 at 0x7FE9BE1BDDD0>
# <PIL.Image.Image image mode=L size=2048x6257 at 0x7FEA94500710>
# ...

# %%
Obfuscator = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/Obfuscator.ACY/'

root = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/'
images_path = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/'
fam = list(os.listdir(root))

# for i in fam:
#     folder_path = os.path.join(images_path,i)
#     os.mkdir(folder_path)
#     print(folder_path)

images_path_Obfuscator_ver1 = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Obfuscator.ACY/'

img_list_2 = []
for img in os.listdir(Obfuscator):
    Obfuscator_path = os.path.join(Obfuscator, img)
    img_list_2.append(Obfuscator_path)

for j in img_list_2:
    f = open(j, 'rb')
    ln = os.path.getsize(j)

    if ln < 10240:
        width = 32
    elif ln < 30720:
        width = 64
    elif ln < 61440:
        width = 128
    elif ln < 102400:
        width = 256
    elif ln < 204800:
        width = 384
    elif ln < 1024000:
        width = 512
    elif ln < 1536000:
        width = 1024
    else:
        width = 2048

    rem = ln%width
    a = array.array("B")
    a.fromfile(f, ln-rem)
    f.close()
    g = np.reshape(a, (len(a)//width, width))
    g = np.uint8(g)
    
    #scipy.misc.imsave('/home/ubuntu/Desktop/BinImg/%s.png'%j, g)
    #print("Image saved for bin_id %s"%j)
    
    img = Image.fromarray(g)
    print(img)
   # str1 = Gatak_img + j
    
    #result = hashlib.md5(str1.encode())
    #str2 = result.hexdigest()
    img_asm = j.split('/')[-1]
    img_name = img_asm.split('.')[0] +'.png'
    img.save((images_path_Obfuscator_ver1+'/')+ img_name)
# Out:
# <PIL.Image.Image image mode=L size=512x1890 at 0x7FE9BDFC3650>
# <PIL.Image.Image image mode=L size=512x1882 at 0x7FE9BDE68450>
# <PIL.Image.Image image mode=L size=512x1907 at 0x7FE9BDE68610>
# <PIL.Image.Image image mode=L size=2048x988 at 0x7FE9BDE68450>
# <PIL.Image.Image image mode=L size=1024x1419 at 0x7FE9BE53B650>
# <PIL.Image.Image image mode=L size=1024x1385 at 0x7FE9BDE68450>
# <PIL.Image.Image image mode=L size=512x1956 at 0x7FE9BDE68390>
# <PIL.Image.Image image mode=L size=512x1948 at 0x7FE9BDE68450>
# <PIL.Image.Image image mode=L size=1024x1454 at 0x7FE9BDE68390>
# <PIL.Image.Image image mode=L size=1024x1385 at 0x7FE9BDE68450>
# <PIL.Image.Image image mode=L size=1024x1022 at 0x7FE9BDE68610>
# <PIL.Image.Image image mode=L size=2048x754 at 0x7FE9BDE68450>
# <PIL.Image.Image image mode=L size=512x1873 at 0x7FE9BDE68590>
# <PIL.Image.Image image mode=L size=512x1998 at 0x7FE9BDE68610>
# <PIL.Image.Image image mode=L size=512x1931 at 0x7FE9BDE68450>
# ...

# %%
Ramnit = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/Ramnit/'

root = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/'
images_path = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/'
fam = list(os.listdir(root))

# for i in fam:
#     folder_path = os.path.join(images_path,i)
#     os.mkdir(folder_path)
#     print(folder_path)

images_path_Ramnit_ver1 = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Ramnit/'

img_list_2 = []
for img in os.listdir(Ramnit):
    Ramnit_path = os.path.join(Ramnit, img)
    img_list_2.append(Ramnit_path)

for j in img_list_2:
    f = open(j, 'rb')
    ln = os.path.getsize(j)

    if ln < 10240:
        width = 32
    elif ln < 30720:
        width = 64
    elif ln < 61440:
        width = 128
    elif ln < 102400:
        width = 256
    elif ln < 204800:
        width = 384
    elif ln < 1024000:
        width = 512
    elif ln < 1536000:
        width = 1024
    else:
        width = 2048

    rem = ln%width
    a = array.array("B")
    a.fromfile(f, ln-rem)
    f.close()
    g = np.reshape(a, (len(a)//width, width))
    g = np.uint8(g)
    
    #scipy.misc.imsave('/home/ubuntu/Desktop/BinImg/%s.png'%j, g)
    #print("Image saved for bin_id %s"%j)
    
    img = Image.fromarray(g)
    print(img)
   # str1 = Gatak_img + j
    
    #result = hashlib.md5(str1.encode())
    #str2 = result.hexdigest()
    img_asm = j.split('/')[-1]
    img_name = img_asm.split('.')[0] +'.png'
    img.save((images_path_Ramnit_ver1+'/')+ img_name)
# Out:
# <PIL.Image.Image image mode=L size=2048x3834 at 0x7FE9BDE7FD50>
# <PIL.Image.Image image mode=L size=2048x1329 at 0x7FE9BDE7FE90>
# <PIL.Image.Image image mode=L size=2048x1065 at 0x7FE9BDE7FF50>
# <PIL.Image.Image image mode=L size=1024x1436 at 0x7FE9BDE7FF90>
# <PIL.Image.Image image mode=L size=2048x781 at 0x7FE9BDE7FDD0>
# <PIL.Image.Image image mode=L size=1024x1136 at 0x7FE9BDE7FF90>
# <PIL.Image.Image image mode=L size=1024x1113 at 0x7FE9BDE7FF10>
# <PIL.Image.Image image mode=L size=512x632 at 0x7FE9BDE7FE10>
# <PIL.Image.Image image mode=L size=512x1890 at 0x7FE9BDE7FE90>
# <PIL.Image.Image image mode=L size=2048x2132 at 0x7FE9BDE7FE10>
# <PIL.Image.Image image mode=L size=2048x1724 at 0x7FE9BDE7FDD0>
# <PIL.Image.Image image mode=L size=2048x2900 at 0x7FE9BDE7FD50>
# <PIL.Image.Image image mode=L size=2048x877 at 0x7FE9BDE7FE10>
# <PIL.Image.Image image mode=L size=2048x3163 at 0x7FE9BDE7FF10>
# <PIL.Image.Image image mode=L size=2048x2746 at 0x7FE9BDE7FD50>
# ...

# %%
Simda = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/Simda/'

root = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/'
images_path = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/'
fam = list(os.listdir(root))

# for i in fam:
#     folder_path = os.path.join(images_path,i)
#     os.mkdir(folder_path)
#     print(folder_path)

images_path_Simda_ver1 = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Simda/'

img_list_2 = []
for img in os.listdir(Simda):
    Simda_path = os.path.join(Simda, img)
    img_list_2.append(Simda_path)

for j in img_list_2:
    f = open(j, 'rb')
    ln = os.path.getsize(j)

    if ln < 10240:
        width = 32
    elif ln < 30720:
        width = 64
    elif ln < 61440:
        width = 128
    elif ln < 102400:
        width = 256
    elif ln < 204800:
        width = 384
    elif ln < 1024000:
        width = 512
    elif ln < 1536000:
        width = 1024
    else:
        width = 2048

    rem = ln%width
    a = array.array("B")
    a.fromfile(f, ln-rem)
    f.close()
    g = np.reshape(a, (len(a)//width, width))
    g = np.uint8(g)
    
    #scipy.misc.imsave('/home/ubuntu/Desktop/BinImg/%s.png'%j, g)
    #print("Image saved for bin_id %s"%j)
    
    img = Image.fromarray(g)
    print(img)
   # str1 = Gatak_img + j
    
    #result = hashlib.md5(str1.encode())
    #str2 = result.hexdigest()
    img_asm = j.split('/')[-1]
    img_name = img_asm.split('.')[0] +'.png'
    img.save((images_path_Simda_ver1+'/')+ img_name)
# Out:
# <PIL.Image.Image image mode=L size=2048x4631 at 0x7FE9BDF8DC90>
# <PIL.Image.Image image mode=L size=2048x5124 at 0x7FE9BDF8DAD0>
# <PIL.Image.Image image mode=L size=2048x4959 at 0x7FE9BDF8DF90>
# <PIL.Image.Image image mode=L size=2048x4913 at 0x7FE9BDF8DDD0>
# <PIL.Image.Image image mode=L size=2048x5195 at 0x7FE9BDF8DC90>
# <PIL.Image.Image image mode=L size=1024x1315 at 0x7FE9BDF8DAD0>
# <PIL.Image.Image image mode=L size=512x1657 at 0x7FE9BDF8DF90>
# <PIL.Image.Image image mode=L size=1024x1207 at 0x7FE9BDECA290>
# <PIL.Image.Image image mode=L size=1024x1278 at 0x7FE9BDF8DDD0>
# <PIL.Image.Image image mode=L size=512x1827 at 0x7FE9BDF8DAD0>
# <PIL.Image.Image image mode=L size=512x1105 at 0x7FE9BDF8DC90>
# <PIL.Image.Image image mode=L size=2048x4946 at 0x7FE9BE24C6D0>
# <PIL.Image.Image image mode=L size=2048x4785 at 0x7FE9BDF8DC90>
# <PIL.Image.Image image mode=L size=2048x989 at 0x7FE9BDF8DF90>
# <PIL.Image.Image image mode=L size=1024x1116 at 0x7FE9BDF8DAD0>
# ...

# %%
Tracur = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/Tracur/'

root = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/'
images_path = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/'
fam = list(os.listdir(root))

# for i in fam:
#     folder_path = os.path.join(images_path,i)
#     os.mkdir(folder_path)
#     print(folder_path)

images_path_Tracur_ver1 = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Tracur/'

img_list_2 = []
for img in os.listdir(Tracur):
    Tracur_path = os.path.join(Tracur, img)
    img_list_2.append(Tracur_path)

for j in img_list_2:
    f = open(j, 'rb')
    ln = os.path.getsize(j)

    if ln < 10240:
        width = 32
    elif ln < 30720:
        width = 64
    elif ln < 61440:
        width = 128
    elif ln < 102400:
        width = 256
    elif ln < 204800:
        width = 384
    elif ln < 1024000:
        width = 512
    elif ln < 1536000:
        width = 1024
    else:
        width = 2048

    rem = ln%width
    a = array.array("B")
    a.fromfile(f, ln-rem)
    f.close()
    g = np.reshape(a, (len(a)//width, width))
    g = np.uint8(g)
    
    #scipy.misc.imsave('/home/ubuntu/Desktop/BinImg/%s.png'%j, g)
    #print("Image saved for bin_id %s"%j)
    
    img = Image.fromarray(g)
    print(img)
   # str1 = Gatak_img + j
    
    #result = hashlib.md5(str1.encode())
    #str2 = result.hexdigest()
    img_asm = j.split('/')[-1]
    img_name = img_asm.split('.')[0] +'.png'
    img.save((images_path_Tracur_ver1+'/')+ img_name)
# Out:
# <PIL.Image.Image image mode=L size=2048x1976 at 0x7FE9BDE68950>
# <PIL.Image.Image image mode=L size=2048x15548 at 0x7FE9BDE68910>
# <PIL.Image.Image image mode=L size=2048x2872 at 0x7FEA945157D0>
# <PIL.Image.Image image mode=L size=2048x1151 at 0x7FE9BDE68490>
# <PIL.Image.Image image mode=L size=512x1603 at 0x7FEA94515050>
# <PIL.Image.Image image mode=L size=2048x1985 at 0x7FE9BDE68490>
# <PIL.Image.Image image mode=L size=2048x2672 at 0x7FEA94515050>
# <PIL.Image.Image image mode=L size=2048x11091 at 0x7FE9BDE68C50>
# <PIL.Image.Image image mode=L size=2048x2664 at 0x7FE9BE24C6D0>
# <PIL.Image.Image image mode=L size=2048x2592 at 0x7FE9BDE68890>
# <PIL.Image.Image image mode=L size=2048x2281 at 0x7FE9BE24C6D0>
# <PIL.Image.Image image mode=L size=2048x1984 at 0x7FE9BDE68910>
# <PIL.Image.Image image mode=L size=2048x2105 at 0x7FEA94515050>
# <PIL.Image.Image image mode=L size=2048x3079 at 0x7FE9BDE68490>
# <PIL.Image.Image image mode=L size=2048x3168 at 0x7FE9BE24C6D0>
# ...

# %%
Vundo = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/Vundo/'

root = '/home/sanjeev/ML_Dataset/microsoft_dataset/dataset_asm/'
images_path = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/'
fam = list(os.listdir(root))

# for i in fam:
#     folder_path = os.path.join(images_path,i)
#     os.mkdir(folder_path)
#     print(folder_path)

images_path_Vundo_ver1 = '/home/sanjeev/ML_Dataset/microsoft_dataset/asm_img_Gatak/Vundo/'

img_list_2 = []
for img in os.listdir(Vundo):
    Vundo_path = os.path.join(Vundo, img)
    img_list_2.append(Vundo_path)

for j in img_list_2:
    f = open(j, 'rb')
    ln = os.path.getsize(j)

    if ln < 10240:
        width = 32
    elif ln < 30720:
        width = 64
    elif ln < 61440:
        width = 128
    elif ln < 102400:
        width = 256
    elif ln < 204800:
        width = 384
    elif ln < 1024000:
        width = 512
    elif ln < 1536000:
        width = 1024
    else:
        width = 2048

    rem = ln%width
    a = array.array("B")
    a.fromfile(f, ln-rem)
    f.close()
    g = np.reshape(a, (len(a)//width, width))
    g = np.uint8(g)
    
    #scipy.misc.imsave('/home/ubuntu/Desktop/BinImg/%s.png'%j, g)
    #print("Image saved for bin_id %s"%j)
    
    img = Image.fromarray(g)
    print(img)
   # str1 = Gatak_img + j
    
    #result = hashlib.md5(str1.encode())
    #str2 = result.hexdigest()
    img_asm = j.split('/')[-1]
    img_name = img_asm.split('.')[0] +'.png'
    img.save((images_path_Vundo_ver1+'/')+ img_name)
# Out:
# <PIL.Image.Image image mode=L size=2048x2493 at 0x7FE9BDEF5210>
# <PIL.Image.Image image mode=L size=2048x5604 at 0x7FE9BDEF52D0>
# <PIL.Image.Image image mode=L size=2048x5610 at 0x7FE9BDEE8590>
# <PIL.Image.Image image mode=L size=2048x1892 at 0x7FE9BDEE8110>
# <PIL.Image.Image image mode=L size=2048x2031 at 0x7FE9BE6BA210>
# <PIL.Image.Image image mode=L size=2048x5769 at 0x7FE9BDEE8110>
# <PIL.Image.Image image mode=L size=2048x1938 at 0x7FE9BDEE8A90>
# <PIL.Image.Image image mode=L size=2048x4207 at 0x7FE9BDEE8A50>
# <PIL.Image.Image image mode=L size=2048x2144 at 0x7FE9BDEE8590>
# <PIL.Image.Image image mode=L size=2048x1951 at 0x7FE9BDEE8110>
# <PIL.Image.Image image mode=L size=2048x1742 at 0x7FEA94515050>
# <PIL.Image.Image image mode=L size=2048x1788 at 0x7FE9BDEE8110>
# <PIL.Image.Image image mode=L size=2048x1725 at 0x7FEA94515050>
# <PIL.Image.Image image mode=L size=2048x5479 at 0x7FE9BDEE8110>
# <PIL.Image.Image image mode=L size=2048x5705 at 0x7FE9BDEE8A90>
# ...

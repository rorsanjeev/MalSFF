# %%
import os
import cv2
import glob
import random
import warnings
import numpy as np
import disarray as da
import seaborn as sns
import tensorflow as tf
from imutils import paths
from itertools import cycle
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

# %%
tf.compat.v1.disable_eager_execution()

# %%
base_path = '/home/sanjeev/ML_Dataset/Malimg_data' # Data Path 
img_list = glob.glob(os.path.join(base_path, '*/*.png'))

# %%
img_list = glob.glob(os.path.join(base_path, '*/*.png'))

# %%
len(img_list)
# Out:
# 9339

# %%
# classes in malimg data
categories = os.listdir(base_path)
labels = [i for i in range(len(categories))]
label_dict = dict(zip(categories, labels))

# %%
# Get the current working directory
cur_dir = os.getcwd()
os.chdir(base_path)  # Navigate to the parent folder with sub-folders

# Get number of samples per family
list_fams = sorted([f for f in os.listdir(os.getcwd()) if os.path.isdir(f)], key=str.lower)  # Only directories
no_imgs = []  # Number of samples per family

for fam in list_fams:
    os.chdir(fam)
    len1 = len(glob.glob('*.png'))  # Assuming the images are stored as 'png'
    no_imgs.append(len1)
    os.chdir('..')
num_samples = np.sum(no_imgs)  # Total number of all samples

# Compute the labels
y = np.zeros(num_samples)
pos = 0
label = 0
fam = []
for i, no_img in enumerate(no_imgs):
    print("Label:%2d\tFamily: %15s\tNumber of images: %d" % (label, list_fams[label], no_img))
    for _ in range(no_img):
        y[pos] = label
        pos += 1
        fam.append(list_fams[label])
    label += 1
num_classes = label
# Out:
# Label: 0	Family:       Adialer.C	Number of images: 122
# Label: 1	Family:       Agent.FYI	Number of images: 116
# Label: 2	Family:       Allaple.A	Number of images: 2949
# Label: 3	Family:       Allaple.L	Number of images: 1591
# Label: 4	Family:   Alueron.gen!J	Number of images: 198
# Label: 5	Family:       Autorun.K	Number of images: 106
# Label: 6	Family:     C2LOP.gen!g	Number of images: 200
# Label: 7	Family:         C2LOP.P	Number of images: 146
# Label: 8	Family:  Dialplatform.B	Number of images: 177
# Label: 9	Family:       Dontovo.A	Number of images: 162
# Label:10	Family:        Fakerean	Number of images: 381
# Label:11	Family:   Instantaccess	Number of images: 431
# Label:12	Family:      Lolyda.AA1	Number of images: 213
# Label:13	Family:      Lolyda.AA2	Number of images: 184
# Label:14	Family:      Lolyda.AA3	Number of images: 123
# Label:15	Family:       Lolyda.AT	Number of images: 159
# Label:16	Family:     Malex.gen!J	Number of images: 136
# Label:17	Family:   Obfuscator.AD	Number of images: 142
# Label:18	Family:        Rbot!gen	Number of images: 158
# Label:19	Family:      Skintrim.N	Number of images: 80
# Label:20	Family:   Swizzor.gen!E	Number of images: 128
# Label:21	Family:   Swizzor.gen!I	Number of images: 132
# Label:22	Family:           VB.AT	Number of images: 408
# Label:23	Family:      Wintrim.BX	Number of images: 97
# Label:24	Family:         Yuner.A	Number of images: 800

# %%
# Sample images from dataset
for i, img_path in enumerate(random.sample(img_list, 6)):
    img = image.load_img(img_path, target_size=(224, 224))
    img = image.img_to_array(img, dtype=np.uint8)
    plt.subplot(2, 3, i+1)
    plt.imshow(img.squeeze())

# %%
base_model = MobileNetV3Large(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Add a global average pooling layer to the model
x = base_model.output
x = GlobalAveragePooling2D()(x)
base_model.trainable = False

# %%
# Set the output shape of the model to (None, 1024)
model = Model(inputs=base_model.input, outputs=x)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 224, 224, 3)  0           ['input_2[0][0]']
#
#  Conv (Conv2D)                  (None, 112, 112, 16  432         ['rescaling_1[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 112, 112, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf_op_layer_add_29 (TensorFlow  [(None, 112, 112, 1  0          ['Conv/BatchNorm[0][0]']
#  OpLayer)                       6)]
#
#  re_lu_40 (ReLU)                (None, 112, 112, 16  0           ['tf_op_layer_add_29[0][0]']
#                                 )
#
#  tf_op_layer_mul_28 (TensorFlow  [(None, 112, 112, 1  0          ['re_lu_40[0][0]']
#  OpLayer)                       6)]
#
#  multiply_21 (Multiply)         (None, 112, 112, 16  0           ['Conv/BatchNorm[0][0]',
#                                 )                                 'tf_op_layer_mul_28[0][0]']
#
#  expanded_conv/depthwise (Depth  (None, 112, 112, 16  144        ['multiply_21[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv/depthwise/BatchN  (None, 112, 112, 16  64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       )
#
#  re_lu_41 (ReLU)                (None, 112, 112, 16  0           ['expanded_conv/depthwise/BatchNo
#                                 )                                rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 112, 112, 16  256        ['re_lu_41[0][0]']
#                                 )
#
#  expanded_conv/project/BatchNor  (None, 112, 112, 16  64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         )
#
#  expanded_conv/Add (Add)        (None, 112, 112, 16  0           ['multiply_21[0][0]',
#                                 )                                 'expanded_conv/project/BatchNorm
#                                                                  [0][0]']
#
#  expanded_conv_1/expand (Conv2D  (None, 112, 112, 64  1024       ['expanded_conv/Add[0][0]']
#  )                              )
#
#  expanded_conv_1/expand/BatchNo  (None, 112, 112, 64  256        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_42 (ReLU)                (None, 112, 112, 64  0           ['expanded_conv_1/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 113, 113, 64  0          ['re_lu_42[0][0]']
#  (ZeroPadding2D)                )
#
#  expanded_conv_1/depthwise (Dep  (None, 56, 56, 64)  576         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 56, 56, 64)  256         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_43 (ReLU)                (None, 56, 56, 64)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 56, 56, 24)  1536        ['re_lu_43[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 56, 56, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 56, 56, 72)  1728        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 56, 56, 72)  288         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_44 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 56, 56, 72)  648         ['re_lu_44[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 56, 56, 72)  288         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_45 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 56, 56, 24)  1728        ['re_lu_45[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 56, 56, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 56, 56, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 56, 56, 72)  1728        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 56, 56, 72)  288         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_46 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 59, 59, 72)  0           ['re_lu_46[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 28, 28, 72)  1800        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 28, 28, 72)  288         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_47 (ReLU)                (None, 28, 28, 72)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    0           ['re_lu_47[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    1752        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    1800        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf_op_layer_add_30 (TensorFlow  [(None, 1, 1, 72)]  0           ['expanded_conv_3/squeeze_excite/
#  OpLayer)                                                        Conv_1[0][0]']
#
#  re_lu_48 (ReLU)                (None, 1, 1, 72)     0           ['tf_op_layer_add_30[0][0]']
#
#  tf_op_layer_mul_29 (TensorFlow  [(None, 1, 1, 72)]  0           ['re_lu_48[0][0]']
#  OpLayer)
#
#  expanded_conv_3/squeeze_excite  (None, 28, 28, 72)  0           ['re_lu_47[0][0]',
#  /Mul (Multiply)                                                  'tf_op_layer_mul_29[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 28, 28, 40)  2880        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 28, 28, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 28, 28, 120)  4800       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 28, 28, 120)  480        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_49 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 28, 28, 120)  3000       ['re_lu_49[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 28, 28, 120)  480        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_50 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_50[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf_op_layer_add_31 (TensorFlow  [(None, 1, 1, 120)]  0          ['expanded_conv_4/squeeze_excite/
#  OpLayer)                                                        Conv_1[0][0]']
#
#  re_lu_51 (ReLU)                (None, 1, 1, 120)    0           ['tf_op_layer_add_31[0][0]']
#
#  tf_op_layer_mul_30 (TensorFlow  [(None, 1, 1, 120)]  0          ['re_lu_51[0][0]']
#  OpLayer)
#
#  expanded_conv_4/squeeze_excite  (None, 28, 28, 120)  0          ['re_lu_50[0][0]',
#  /Mul (Multiply)                                                  'tf_op_layer_mul_30[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 28, 28, 40)  4800        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 28, 28, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 28, 28, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 28, 28, 120)  4800       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 28, 28, 120)  480        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_52 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 28, 28, 120)  3000       ['re_lu_52[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 28, 28, 120)  480        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_53 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_53[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf_op_layer_add_32 (TensorFlow  [(None, 1, 1, 120)]  0          ['expanded_conv_5/squeeze_excite/
#  OpLayer)                                                        Conv_1[0][0]']
#
#  re_lu_54 (ReLU)                (None, 1, 1, 120)    0           ['tf_op_layer_add_32[0][0]']
#
#  tf_op_layer_mul_31 (TensorFlow  [(None, 1, 1, 120)]  0          ['re_lu_54[0][0]']
#  OpLayer)
#
#  expanded_conv_5/squeeze_excite  (None, 28, 28, 120)  0          ['re_lu_53[0][0]',
#  /Mul (Multiply)                                                  'tf_op_layer_mul_31[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 28, 28, 40)  4800        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 28, 28, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 28, 28, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 28, 28, 240)  9600       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 28, 28, 240)  960        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf_op_layer_add_33 (TensorFlow  [(None, 28, 28, 240  0          ['expanded_conv_6/expand/BatchNor
#  OpLayer)                       )]                               m[0][0]']
#
#  re_lu_55 (ReLU)                (None, 28, 28, 240)  0           ['tf_op_layer_add_33[0][0]']
#
#  tf_op_layer_mul_32 (TensorFlow  [(None, 28, 28, 240  0          ['re_lu_55[0][0]']
#  OpLayer)                       )]
#
#  multiply_22 (Multiply)         (None, 28, 28, 240)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf_op_layer_mul_32[0][0]']
#
#  expanded_conv_6/depthwise/pad   (None, 29, 29, 240)  0          ['multiply_22[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_6/depthwise (Dep  (None, 14, 14, 240)  2160       ['expanded_conv_6/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_6/depthwise/Batc  (None, 14, 14, 240)  960        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf_op_layer_add_34 (TensorFlow  [(None, 14, 14, 240  0          ['expanded_conv_6/depthwise/Batch
#  OpLayer)                       )]                               Norm[0][0]']
#
#  re_lu_56 (ReLU)                (None, 14, 14, 240)  0           ['tf_op_layer_add_34[0][0]']
#
#  tf_op_layer_mul_33 (TensorFlow  [(None, 14, 14, 240  0          ['re_lu_56[0][0]']
#  OpLayer)                       )]
#
#  multiply_23 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf_op_layer_mul_33[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 14, 14, 80)  19200       ['multiply_23[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 14, 14, 200)  16000      ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 14, 14, 200)  800        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf_op_layer_add_35 (TensorFlow  [(None, 14, 14, 200  0          ['expanded_conv_7/expand/BatchNor
#  OpLayer)                       )]                               m[0][0]']
#
#  re_lu_57 (ReLU)                (None, 14, 14, 200)  0           ['tf_op_layer_add_35[0][0]']
#
#  tf_op_layer_mul_34 (TensorFlow  [(None, 14, 14, 200  0          ['re_lu_57[0][0]']
#  OpLayer)                       )]
#
#  multiply_24 (Multiply)         (None, 14, 14, 200)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf_op_layer_mul_34[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 14, 14, 200)  1800       ['multiply_24[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 14, 14, 200)  800        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf_op_layer_add_36 (TensorFlow  [(None, 14, 14, 200  0          ['expanded_conv_7/depthwise/Batch
#  OpLayer)                       )]                               Norm[0][0]']
#
#  re_lu_58 (ReLU)                (None, 14, 14, 200)  0           ['tf_op_layer_add_36[0][0]']
#
#  tf_op_layer_mul_35 (TensorFlow  [(None, 14, 14, 200  0          ['re_lu_58[0][0]']
#  OpLayer)                       )]
#
#  multiply_25 (Multiply)         (None, 14, 14, 200)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf_op_layer_mul_35[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 14, 14, 80)  16000       ['multiply_25[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 14, 14, 80)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 14, 14, 184)  14720      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 14, 14, 184)  736        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf_op_layer_add_37 (TensorFlow  [(None, 14, 14, 184  0          ['expanded_conv_8/expand/BatchNor
#  OpLayer)                       )]                               m[0][0]']
#
#  re_lu_59 (ReLU)                (None, 14, 14, 184)  0           ['tf_op_layer_add_37[0][0]']
#
#  tf_op_layer_mul_36 (TensorFlow  [(None, 14, 14, 184  0          ['re_lu_59[0][0]']
#  OpLayer)                       )]
#
#  multiply_26 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf_op_layer_mul_36[0][0]']
#
#  expanded_conv_8/depthwise (Dep  (None, 14, 14, 184)  1656       ['multiply_26[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_8/depthwise/Batc  (None, 14, 14, 184)  736        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf_op_layer_add_38 (TensorFlow  [(None, 14, 14, 184  0          ['expanded_conv_8/depthwise/Batch
#  OpLayer)                       )]                               Norm[0][0]']
#
#  re_lu_60 (ReLU)                (None, 14, 14, 184)  0           ['tf_op_layer_add_38[0][0]']
#
#  tf_op_layer_mul_37 (TensorFlow  [(None, 14, 14, 184  0          ['re_lu_60[0][0]']
#  OpLayer)                       )]
#
#  multiply_27 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf_op_layer_mul_37[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 14, 14, 80)  14720       ['multiply_27[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_8/Add (Add)      (None, 14, 14, 80)   0           ['expanded_conv_7/Add[0][0]',
#                                                                   'expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_9/expand (Conv2D  (None, 14, 14, 184)  14720      ['expanded_conv_8/Add[0][0]']
#  )
#
#  expanded_conv_9/expand/BatchNo  (None, 14, 14, 184)  736        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf_op_layer_add_39 (TensorFlow  [(None, 14, 14, 184  0          ['expanded_conv_9/expand/BatchNor
#  OpLayer)                       )]                               m[0][0]']
#
#  re_lu_61 (ReLU)                (None, 14, 14, 184)  0           ['tf_op_layer_add_39[0][0]']
#
#  tf_op_layer_mul_38 (TensorFlow  [(None, 14, 14, 184  0          ['re_lu_61[0][0]']
#  OpLayer)                       )]
#
#  multiply_28 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf_op_layer_mul_38[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 14, 14, 184)  1656       ['multiply_28[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 14, 14, 184)  736        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf_op_layer_add_40 (TensorFlow  [(None, 14, 14, 184  0          ['expanded_conv_9/depthwise/Batch
#  OpLayer)                       )]                               Norm[0][0]']
#
#  re_lu_62 (ReLU)                (None, 14, 14, 184)  0           ['tf_op_layer_add_40[0][0]']
#
#  tf_op_layer_mul_39 (TensorFlow  [(None, 14, 14, 184  0          ['re_lu_62[0][0]']
#  OpLayer)                       )]
#
#  multiply_29 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf_op_layer_mul_39[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 14, 14, 80)  14720       ['multiply_29[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 14, 14, 80)   0           ['expanded_conv_8/Add[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 14, 14, 480)  38400      ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 14, 14, 480)  1920       ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf_op_layer_add_41 (TensorFlow  [(None, 14, 14, 480  0          ['expanded_conv_10/expand/BatchNo
#  OpLayer)                       )]                               rm[0][0]']
#
#  re_lu_63 (ReLU)                (None, 14, 14, 480)  0           ['tf_op_layer_add_41[0][0]']
#
#  tf_op_layer_mul_40 (TensorFlow  [(None, 14, 14, 480  0          ['re_lu_63[0][0]']
#  OpLayer)                       )]
#
#  multiply_30 (Multiply)         (None, 14, 14, 480)  0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf_op_layer_mul_40[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 14, 14, 480)  4320       ['multiply_30[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 14, 14, 480)  1920       ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf_op_layer_add_42 (TensorFlow  [(None, 14, 14, 480  0          ['expanded_conv_10/depthwise/Batc
#  OpLayer)                       )]                               hNorm[0][0]']
#
#  re_lu_64 (ReLU)                (None, 14, 14, 480)  0           ['tf_op_layer_add_42[0][0]']
#
#  tf_op_layer_mul_41 (TensorFlow  [(None, 14, 14, 480  0          ['re_lu_64[0][0]']
#  OpLayer)                       )]
#
#  multiply_31 (Multiply)         (None, 14, 14, 480)  0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf_op_layer_mul_41[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 480)   0           ['multiply_31[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   57720       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
# ...
#  pthwiseConv2D)
#
#  expanded_conv_13/depthwise/Bat  (None, 7, 7, 960)   3840        ['expanded_conv_13/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf_op_layer_add_51 (TensorFlow  [(None, 7, 7, 960)]  0          ['expanded_conv_13/depthwise/Batc
#  OpLayer)                                                        hNorm[0][0]']
#
#  re_lu_73 (ReLU)                (None, 7, 7, 960)    0           ['tf_op_layer_add_51[0][0]']
#
#  tf_op_layer_mul_50 (TensorFlow  [(None, 7, 7, 960)]  0          ['re_lu_73[0][0]']
#  OpLayer)
#
#  multiply_37 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_13/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf_op_layer_mul_50[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_37[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_13/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_13/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_13/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf_op_layer_add_52 (TensorFlow  [(None, 1, 1, 960)]  0          ['expanded_conv_13/squeeze_excite
#  OpLayer)                                                        /Conv_1[0][0]']
#
#  re_lu_74 (ReLU)                (None, 1, 1, 960)    0           ['tf_op_layer_add_52[0][0]']
#
#  tf_op_layer_mul_51 (TensorFlow  [(None, 1, 1, 960)]  0          ['re_lu_74[0][0]']
#  OpLayer)
#
#  expanded_conv_13/squeeze_excit  (None, 7, 7, 960)   0           ['multiply_37[0][0]',
#  e/Mul (Multiply)                                                 'tf_op_layer_mul_51[0][0]']
#
#  expanded_conv_13/project (Conv  (None, 7, 7, 160)   153600      ['expanded_conv_13/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_13/project/Batch  (None, 7, 7, 160)   640         ['expanded_conv_13/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_13/Add (Add)     (None, 7, 7, 160)    0           ['expanded_conv_12/project/BatchN
#                                                                  orm[0][0]',
#                                                                   'expanded_conv_13/project/BatchN
#                                                                  orm[0][0]']
#
#  expanded_conv_14/expand (Conv2  (None, 7, 7, 960)   153600      ['expanded_conv_13/Add[0][0]']
#  D)
#
#  expanded_conv_14/expand/BatchN  (None, 7, 7, 960)   3840        ['expanded_conv_14/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf_op_layer_add_53 (TensorFlow  [(None, 7, 7, 960)]  0          ['expanded_conv_14/expand/BatchNo
#  OpLayer)                                                        rm[0][0]']
#
#  re_lu_75 (ReLU)                (None, 7, 7, 960)    0           ['tf_op_layer_add_53[0][0]']
#
#  tf_op_layer_mul_52 (TensorFlow  [(None, 7, 7, 960)]  0          ['re_lu_75[0][0]']
#  OpLayer)
#
#  multiply_38 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_14/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf_op_layer_mul_52[0][0]']
#
#  expanded_conv_14/depthwise (De  (None, 7, 7, 960)   24000       ['multiply_38[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_14/depthwise/Bat  (None, 7, 7, 960)   3840        ['expanded_conv_14/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf_op_layer_add_54 (TensorFlow  [(None, 7, 7, 960)]  0          ['expanded_conv_14/depthwise/Batc
#  OpLayer)                                                        hNorm[0][0]']
#
#  re_lu_76 (ReLU)                (None, 7, 7, 960)    0           ['tf_op_layer_add_54[0][0]']
#
#  tf_op_layer_mul_53 (TensorFlow  [(None, 7, 7, 960)]  0          ['re_lu_76[0][0]']
#  OpLayer)
#
#  multiply_39 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_14/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf_op_layer_mul_53[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_39[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_14/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_14/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_14/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf_op_layer_add_55 (TensorFlow  [(None, 1, 1, 960)]  0          ['expanded_conv_14/squeeze_excite
#  OpLayer)                                                        /Conv_1[0][0]']
#
#  re_lu_77 (ReLU)                (None, 1, 1, 960)    0           ['tf_op_layer_add_55[0][0]']
#
#  tf_op_layer_mul_54 (TensorFlow  [(None, 1, 1, 960)]  0          ['re_lu_77[0][0]']
#  OpLayer)
#
#  expanded_conv_14/squeeze_excit  (None, 7, 7, 960)   0           ['multiply_39[0][0]',
#  e/Mul (Multiply)                                                 'tf_op_layer_mul_54[0][0]']
#
#  expanded_conv_14/project (Conv  (None, 7, 7, 160)   153600      ['expanded_conv_14/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_14/project/Batch  (None, 7, 7, 160)   640         ['expanded_conv_14/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_14/Add (Add)     (None, 7, 7, 160)    0           ['expanded_conv_13/Add[0][0]',
#                                                                   'expanded_conv_14/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 7, 7, 960)    153600      ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 7, 7, 960)   3840        ['Conv_1[0][0]']
#  zation)
#
#  tf_op_layer_add_56 (TensorFlow  [(None, 7, 7, 960)]  0          ['Conv_1/BatchNorm[0][0]']
#  OpLayer)
#
#  re_lu_78 (ReLU)                (None, 7, 7, 960)    0           ['tf_op_layer_add_56[0][0]']
#
#  tf_op_layer_mul_55 (TensorFlow  [(None, 7, 7, 960)]  0          ['re_lu_78[0][0]']
#  OpLayer)
#
#  multiply_40 (Multiply)         (None, 7, 7, 960)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf_op_layer_mul_55[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1, 1, 960)   0           ['multiply_40[0][0]']
#  obalAveragePooling2D)
#
#  Conv_2 (Conv2D)                (None, 1, 1, 1280)   1230080     ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  tf_op_layer_add_57 (TensorFlow  [(None, 1, 1, 1280)  0          ['Conv_2[0][0]']
#  OpLayer)                       ]
#
#  re_lu_79 (ReLU)                (None, 1, 1, 1280)   0           ['tf_op_layer_add_57[0][0]']
#
#  tf_op_layer_mul_56 (TensorFlow  [(None, 1, 1, 1280)  0          ['re_lu_79[0][0]']
#  OpLayer)                       ]
#
#  multiply_41 (Multiply)         (None, 1, 1, 1280)   0           ['Conv_2[0][0]',
#                                                                   'tf_op_layer_mul_56[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 1280)        0           ['multiply_41[0][0]']
#  obalAveragePooling2D)
#
# ==================================================================================================
# Total params: 4,226,432
# Trainable params: 0
# Non-trainable params: 4,226,432
# __________________________________________________________________________________________________

# %%
data_labels = set(categories)
image_path = list(paths.list_images(base_path))
images = []                                                   # appending trainable features from MobileNetV1
labels = []                                                   # appending trainable lables from MobileNetV1
img_width = 224                                               # Image size
img_height = 224

# %%
for img in image_path:
    label = img.split(os.path.sep)[-2]
    image = cv2.imread(img)                                    # Reading images using CV2
    rezise_image = cv2.resize(image, (img_width, img_height))  # Resizing Images
    x = np.expand_dims(rezise_image, axis=0)                   # Converting x into 1-D array
    x = preprocess_input(x)
    
    ##features extracted from mobilenetv2 global avg pooling layer
    features = model.predict(x)                                # Predicting features of X
    images.append(features)                                    # Appending features to train_features
    labels.append(label)

# %%
x = np.concatenate(images, axis=0)
y = np.array(labels)

# %%
x.shape
# Out:
# (9340, 1280)

# %%
len(images)
# Out:
# 9340

# %%
pwd()
# Out:
# '/home/sanjeev/ML_Dataset/Malimg_data'

# %%
np.save('/home/sanjeev/DL_Exp_Malware/DL_Prasad_Exp/Microsoft_PoC/after_research/features/MobileNet_V3_large_trainable_features_malimg.npy', x)
np.save('/home/sanjeev/DL_Exp_Malware/DL_Prasad_Exp/Microsoft_PoC/after_research/features/MobileNet_V3_large_trianable_labels_malimg.npy', y)

# %%
features = np.load('/home/sanjeev/DL_Exp_Malware/DL_Prasad_Exp/Microsoft_PoC/after_research/features/MobileNet_V3_large_trainable_features_malimg.npy')  
labels = np.load('/home/sanjeev/DL_Exp_Malware/DL_Prasad_Exp/Microsoft_PoC/after_research/features/MobileNet_V3_large_trianable_labels_malimg.npy')

# %%
print(features.shape)
print(labels.shape)
# Out:
# (9340, 1280)
# (9340,)

# %%
labels.shape
# Out:
# (9340,)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
label_encoder = LabelEncoder()
int_labels = label_encoder.fit_transform(labels)

# %%
int_labels.shape
# Out:
# (9340,)

# %%
one_hot_encoder = OneHotEncoder(sparse=False)

# %%
one_hot_labels = one_hot_encoder.fit_transform(int_labels.reshape(-1, 1))

# %%
print("One-hot label shape:", one_hot_labels.shape)
# Out:
# One-hot label shape: (9340, 26)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    np.array(images).squeeze(), one_hot_labels, test_size=0.2, random_state=42
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define the model
model = Sequential([
    Dense(512, activation='relu', input_shape=(1280,)),
    Dropout(0.5),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(y_train.shape[1], activation='softmax')  # Number of classes in the dataset
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               655872
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 26)                6682
#
# =================================================================
# Total params: 793,882
# Trainable params: 793,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_object = tf.keras.losses.CategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2)
# Out:
# Train on 5977 samples, validate on 1495 samples
# Epoch 1/30
# 5977/5977 [==============================] - 2s 378us/sample - loss: 0.7159 - accuracy: 0.8074 - val_loss: 0.1949 - val_accuracy: 0.9304
# Epoch 2/30
# 5977/5977 [==============================] - 1s 159us/sample - loss: 0.2655 - accuracy: 0.9199 - val_loss: 0.1335 - val_accuracy: 0.9538
# Epoch 3/30
# 5977/5977 [==============================] - 1s 162us/sample - loss: 0.1963 - accuracy: 0.9373 - val_loss: 0.1288 - val_accuracy: 0.9532
# Epoch 4/30
# 5977/5977 [==============================] - 1s 158us/sample - loss: 0.1735 - accuracy: 0.9455 - val_loss: 0.1254 - val_accuracy: 0.9565
# Epoch 5/30
# 5977/5977 [==============================] - 1s 159us/sample - loss: 0.1592 - accuracy: 0.9468 - val_loss: 0.1074 - val_accuracy: 0.9659
# Epoch 6/30
# 5977/5977 [==============================] - 1s 156us/sample - loss: 0.1457 - accuracy: 0.9537 - val_loss: 0.0879 - val_accuracy: 0.9692
# Epoch 7/30
# 5977/5977 [==============================] - 1s 157us/sample - loss: 0.1447 - accuracy: 0.9542 - val_loss: 0.0891 - val_accuracy: 0.9645
# Epoch 8/30
# 5977/5977 [==============================] - 1s 157us/sample - loss: 0.1301 - accuracy: 0.9597 - val_loss: 0.0866 - val_accuracy: 0.9739
# Epoch 9/30
# 5977/5977 [==============================] - 1s 155us/sample - loss: 0.1164 - accuracy: 0.9603 - val_loss: 0.0811 - val_accuracy: 0.9719
# Epoch 10/30
# 5977/5977 [==============================] - 1s 156us/sample - loss: 0.1300 - accuracy: 0.9560 - val_loss: 0.0826 - val_accuracy: 0.9699
# Epoch 11/30
# 5977/5977 [==============================] - 1s 157us/sample - loss: 0.1289 - accuracy: 0.9570 - val_loss: 0.0863 - val_accuracy: 0.9692
# Epoch 12/30
# 5977/5977 [==============================] - 1s 157us/sample - loss: 0.1140 - accuracy: 0.9610 - val_loss: 0.0831 - val_accuracy: 0.9679
# Epoch 13/30
# 5977/5977 [==============================] - 1s 159us/sample - loss: 0.1141 - accuracy: 0.9608 - val_loss: 0.0811 - val_accuracy: 0.9712
# Epoch 14/30
# 5977/5977 [==============================] - 1s 157us/sample - loss: 0.1079 - accuracy: 0.9637 - val_loss: 0.0792 - val_accuracy: 0.9699
# Epoch 15/30
# 5977/5977 [==============================] - 1s 157us/sample - loss: 0.1118 - accuracy: 0.9602 - val_loss: 0.0808 - val_accuracy: 0.9699
# Epoch 16/30
# 5977/5977 [==============================] - 1s 160us/sample - loss: 0.1126 - accuracy: 0.9634 - val_loss: 0.0913 - val_accuracy: 0.9706
# Epoch 17/30
# 5977/5977 [==============================] - 1s 156us/sample - loss: 0.1138 - accuracy: 0.9630 - val_loss: 0.0717 - val_accuracy: 0.9719
# Epoch 18/30
# 5977/5977 [==============================] - 1s 155us/sample - loss: 0.1058 - accuracy: 0.9602 - val_loss: 0.0831 - val_accuracy: 0.9739
# Epoch 19/30
# 5977/5977 [==============================] - 1s 155us/sample - loss: 0.1097 - accuracy: 0.9637 - val_loss: 0.0729 - val_accuracy: 0.9719
# Epoch 20/30
# 5977/5977 [==============================] - 1s 155us/sample - loss: 0.1022 - accuracy: 0.9639 - val_loss: 0.0779 - val_accuracy: 0.9686
# Epoch 21/30
# 5977/5977 [==============================] - 1s 156us/sample - loss: 0.1051 - accuracy: 0.9607 - val_loss: 0.0754 - val_accuracy: 0.9712
# Epoch 22/30
# 5977/5977 [==============================] - 1s 156us/sample - loss: 0.1020 - accuracy: 0.9634 - val_loss: 0.0717 - val_accuracy: 0.9712
# Epoch 23/30
# 5977/5977 [==============================] - 1s 158us/sample - loss: 0.1039 - accuracy: 0.9634 - val_loss: 0.0783 - val_accuracy: 0.9706
# Epoch 24/30
# 5977/5977 [==============================] - 1s 157us/sample - loss: 0.1024 - accuracy: 0.9640 - val_loss: 0.0711 - val_accuracy: 0.9726
# Epoch 25/30
# 5977/5977 [==============================] - 1s 157us/sample - loss: 0.0984 - accuracy: 0.9659 - val_loss: 0.0728 - val_accuracy: 0.9719
# Epoch 26/30
# 5977/5977 [==============================] - 1s 156us/sample - loss: 0.0949 - accuracy: 0.9659 - val_loss: 0.0642 - val_accuracy: 0.9746
# Epoch 27/30
# 5977/5977 [==============================] - 1s 156us/sample - loss: 0.1020 - accuracy: 0.9619 - val_loss: 0.0626 - val_accuracy: 0.9732
# Epoch 28/30
# 5977/5977 [==============================] - 1s 155us/sample - loss: 0.0986 - accuracy: 0.9654 - val_loss: 0.0662 - val_accuracy: 0.9706
# Epoch 29/30
# 5977/5977 [==============================] - 1s 156us/sample - loss: 0.0956 - accuracy: 0.9639 - val_loss: 0.0658 - val_accuracy: 0.9712
# Epoch 30/30
# 5977/5977 [==============================] - 1s 155us/sample - loss: 0.0993 - accuracy: 0.9632 - val_loss: 0.0686 - val_accuracy: 0.9659

# %%
model.save('/home/sanjeev/DL_Exp_Malware/DL_Prasad_Exp/Microsoft_PoC/after_research/features/malware_classifier_adv_1280_malimg.h5')

# %%
import sys
sys.setrecursionlimit(3000)

# %%
from art.estimators.classification import KerasClassifier
from art.attacks.evasion import FastGradientMethod

# %%
# Define the KerasClassifier
classifier = KerasClassifier(model=model, clip_values=(0, 1))

# %%
# Initialize the FGSM (Fast Gradient Sign Method) attack
from art.attacks.evasion import ProjectedGradientDescent
attack = ProjectedGradientDescent(
    estimator=classifier,
    norm=np.inf,          # can also use 2 for L2 PGD
    eps=0.03,             # maximum perturbation
    eps_step=0.007,       # step size per iteration
    max_iter=40,          # number of iterations
    targeted=False,
    batch_size=64
)

# %%
X_test_adv = attack.generate(X_test)
# Out:
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/40 [00:00<?, ?it/s]

# %%
# Test classifier on adversarial examples
y_pred_adv = classifier.predict(X_test_adv)
y_pred_labels = np.argmax(y_pred_adv, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# %%
adv_accuracy = np.mean(y_pred_labels == y_true_labels)
print(f"Adversarial Accuracy: {adv_accuracy * 100:.2f}%")
# Out:
# Adversarial Accuracy: 96.20%

# %%
# Optionally, evaluate on clean test data to compare
y_pred_clean = classifier.predict(X_test)  # Original (clean) test data
y_pred_clean_labels = np.argmax(y_pred_clean, axis=1)

# %%
clean_accuracy = np.mean(y_pred_clean_labels == y_true_labels)
print(f"Clean Test Accuracy: {clean_accuracy * 100:.2f}%")
# Out:
# Clean Test Accuracy: 96.79%

# %%
eps_values = [0.01, 0.05, 0.1, 0.2, 0.3, 0.5, 0.6, 1.5]  # List of epsilon values to test

# %%
results = []

# %%
for eps in eps_values:
    print(f"Testing with eps = {eps}")
    # Initialize FGSM attack with current epsilon
    attack = ProjectedGradientDescent(estimator=classifier, eps=eps)
    
    # Generate adversarial examples
    X_test_adv = attack.generate(X_test)
    
    # Predict on adversarial examples
    y_pred_adv = classifier.predict(X_test_adv)
    y_pred_labels = np.argmax(y_pred_adv, axis=1)
    adv_accuracy = np.mean(y_pred_labels == y_true_labels)
    print(f"Epsilon: {eps}, Adversarial Accuracy: {adv_accuracy * 100:.2f}%")
    
    results.append((eps, adv_accuracy * 100))

# Optionally, print a summary
print("\nSummary of Results:")
for eps, adv_acc in results:
    print(f"Epsilon: {eps:.2f}, Adversarial Accuracy: {adv_acc:.2f}%")
# Out:
# Testing with eps = 0.01
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon: 0.01, Adversarial Accuracy: 96.90%
# Testing with eps = 0.05
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon: 0.05, Adversarial Accuracy: 94.91%
# Testing with eps = 0.1
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon: 0.1, Adversarial Accuracy: 89.35%
# Testing with eps = 0.2
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon: 0.2, Adversarial Accuracy: 33.03%
# Testing with eps = 0.3
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon: 0.3, Adversarial Accuracy: 6.37%
# Testing with eps = 0.5
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon: 0.5, Adversarial Accuracy: 1.28%
# Testing with eps = 0.6
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon: 0.6, Adversarial Accuracy: 1.66%
# Testing with eps = 1.5
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# PGD - Random Initializations:   0%|          | 0/1 [00:00<?, ?it/s]
# PGD - Iterations:   0%|          | 0/100 [00:00<?, ?it/s]
# Epsilon: 1.5, Adversarial Accuracy: 0.80%
#
# Summary of Results:
# Epsilon: 0.01, Adversarial Accuracy: 96.90%
# Epsilon: 0.05, Adversarial Accuracy: 94.91%
# Epsilon: 0.10, Adversarial Accuracy: 89.35%
# Epsilon: 0.20, Adversarial Accuracy: 33.03%
# Epsilon: 0.30, Adversarial Accuracy: 6.37%
# Epsilon: 0.50, Adversarial Accuracy: 1.28%
# Epsilon: 0.60, Adversarial Accuracy: 1.66%
# Epsilon: 1.50, Adversarial Accuracy: 0.80%

# %%
print(f"Data range: {X_train.min()} to {X_train.max()}")
# Out:
# Data range: -0.3750000298023224 to 5.454907417297363

# %%
print("X_test shape:", X_test.shape)
print("One sample shape:", X_test[0].shape)
# Out:
# X_test shape: (1868, 1280)
# One sample shape: (1280,)

# %%
import matplotlib.pyplot as plt

H, W = 40, 32  # because 40*32 = 1280

indices = [0, 1, 2]  # pick sample indices
plt.figure(figsize=(8, 6))

for i, idx in enumerate(indices):
    adv = X_test_adv[idx]
    orig = X_test[idx]
    
    # Adversarial
    plt.subplot(len(indices), 2, i*2 + 1)
    plt.imshow(adv.reshape(H, W), cmap="gray")
    plt.title("Adversarial")
    plt.axis("off")
    
    # Original
    plt.subplot(len(indices), 2, i*2 + 2)
    plt.imshow(orig.reshape(H, W), cmap="gray")
    plt.title("Original")
    plt.axis("off")

plt.tight_layout()
plt.show()
